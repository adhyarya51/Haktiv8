# %% [markdown]
# <a href="https://colab.research.google.com/github/adhyarya51/Python-setup/blob/main/Kisi_Kisi_LC2_P0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')

project_id = "civil-clarity-417802" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id)
# Out:
# Authenticated

# %%
df_1 = client.query('''
SELECT DISTINCT subscriber_type
FROM `ftds-hacktiv8-project.practice.bike_rent`
''').to_dataframe()

df_1
# Out:
#            subscriber_type
# 0                 Explorer
# 1                 Local365
# 2                  Walk Up
# 3                Weekender
# 4                  Local30
# 5  U.T. Student Membership

# %% [markdown]
# # **Kisi-kisi LC2**
#
# Dataset yang digunakan pada latihan ini berasal dari bigquery public data. Lakukan koneksi Google Colaboratory dengan BigQuery menggunakan syntax berikut:
#
# ```
# from google.colab import auth
# from google.cloud import bigquery
# auth.authenticate_user()
# print('Authenticated')
#
# project_id = "hckv8-95102" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
# client = bigquery.Client(project=project_id)
# ```
#
# lalu lakukan query pada notebook menggunakan cara berikut:
#
# ```
# df_1 = client.query('''
# SELECT *
# FROM table_name`
# ''').to_dataframe()
#
# df_1
# ```
#
# ---
#
# Dataset yang digunakan merupakan `record perjalanan peminjam sepeda`, dapat diakses pada:
#
# - **Project_id_Database**: ftds-hacktiv8-project
# - **Dataset**            : practice
# - **Table**              : bike_rent
#
# Lakukan pengolahan SQL langsung melalui Google Colaboratory yang telah dikoneksikan pada BigQuery
#
# ---
# Pada notebook ini terdapat 2 section, **SQL** dan **Pandas**.
#
# Kerjakan masing-masing section sesuai dengan ketentuan di bawah:
#
# ## A. **SQL**
#
#   >**Jawab masing-masing soal dalam 1 query.**
#
#   1. Berapa banyak label unique dari `bike_type`?
#   2. Apa saja nama label unique dari tipe sepeda?
#   3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?
#   4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?
#   5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?
#   6. Berapa rata-rata durasi perjalanan dari subscriber_type `Explorer` dan `Weekender`?
#   7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).
#
# ## B. **Pandas**
#   >**Data yang akan diolah menggunakan Pandas wajib diambil menggunakan Query berikut:**
#   ```
#   SELECT *
#   FROM `ftds-hacktiv8-project.practice.bike_rent`
#   ```
#
#   >Simpan data yang telah diambil ke dalam variabel `df` (penamaan variabel dibebaskan), **lakukan pengolah di bawah ini menggunakan library Pandas**:
#
#   1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`
#
#   2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
#   3. Tampilkan data perjalanan dari tipe member `Local365` dengan durasi perjalanan diatas 1 jam *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
#   4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` berdasarkan data yang diambil? *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
df_1 = client.query('''
SELECT *
FROM `ftds-hacktiv8-project.practice.bike_rent`
''').to_dataframe()

df_1
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %% [markdown]
# ###**SQL**

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_id             8000 non-null   Int64
#  1   subscriber_type     8000 non-null   object
#  2   bike_id             8000 non-null   object
#  3   bike_type           8000 non-null   object
#  4   start_time          8000 non-null   datetime64[ns, UTC]
#  5   start_station_name  8000 non-null   object
#  6   end_station_name    8000 non-null   object
#  7   duration_minutes    8000 non-null   Int64
# dtypes: Int64(2), datetime64[ns, UTC](1), object(5)
# memory usage: 515.8+ KB

# %% [markdown]
# #####1. Berapa banyak label unique dari bike_type?

# %%
# working area
df_1 = client.query('''

SELECT *
FROM `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %%
df_1 = client.query('''

SELECT count(distinct bike_type) as `tipe sepeda`
FROM `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#    tipe sepeda
# 0            2

# %% [markdown]
# #####2. Apa saja nama label unique dari tipe sepeda?

# %%
df_1 = client.query('''

select distinct bike_type as `tipe sepeda`
from `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#   tipe sepeda
# 0     classic
# 1    electric

# %%
# working area
df_1 = client.query('''

SELECT distinct bike_type
FROM `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#   bike_type
# 0   classic
# 1  electric

# %% [markdown]
# #####3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?

# %%
df_1 = client.query('''

select count (start_time)
from `ftds-hacktiv8-project.practice.bike_rent`
where start_time >= '2016-01-01' and start_time < '2018-01-01'

''').to_dataframe()

df_1
# Out:
#     f0_
# 0  7993

# %%
# working area
df_1 = client.query('''

SELECT COUNT (start_time)
FROM `ftds-hacktiv8-project.practice.bike_rent`
WHERE start_time >= '2016-01-01' AND start_time < '2018-01-01'


''').to_dataframe()

df_1
# Out:
#     f0_
# 0  7993

# %% [markdown]
# #####4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?

# %%
df_1 = client.query('''

select start_station_name, count(*) as `jumlah_kunjungan`
from `ftds-hacktiv8-project.practice.bike_rent`
where start_time >= '2016-01-01' and start_time < '2017-01-01'
group by 1
order by jumlah_kunjungan desc
limit 1

''').to_dataframe()

df_1
# Out:
#                 start_station_name  jumlah_kunjungan
# 0  Bullock Museum @ Congress & MLK               394

# %%
# working area
df_1 = client.query('''

SELECT
  start_station_name,
  COUNT (*) as jumlah_kunjungan
FROM `ftds-hacktiv8-project.practice.bike_rent`
WHERE start_time >= '2016-01-01' AND start_time < '2017-01-01'
GROUP BY 1
ORDER BY jumlah_kunjungan DESC
LIMIT 1


''').to_dataframe()

df_1
# Out:
#                 start_station_name  jumlah_kunjungan
# 0  Bullock Museum @ Congress & MLK               394

# %% [markdown]
# #####5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?

# %%
df_1 = client.query('''


select
min(duration_minutes) as minimum_durasi,
max(duration_minutes) as maximum_durasi,
avg(duration_minutes) as rata_rata_durasi
from `ftds-hacktiv8-project.practice.bike_rent`

''').to_dataframe()

df_1
# Out:
#    minimum_durasi  maximum_durasi  rata_rata_durasi
# 0               2            2218           35.0995

# %%
# working area
df_1 = client.query('''

select
  MIN(duration_minutes) as min_duration,
  max(duration_minutes) as max_duration,
  avg(duration_minutes) as avg_duration
from `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#    min_duration  max_duration  avg_duration
# 0             2          2218       35.0995

# %% [markdown]
# #####6. Berapa rata-rata durasi perjalanan dari subscriber_type `Student Membership` dan `Local31`?

# %%
df_1 = client.query('''

select distinct subscriber_type
from `ftds-hacktiv8-project.practice.bike_rent`

''').to_dataframe()

df_1
# Out:
#            subscriber_type
# 0                 Explorer
# 1                 Local365
# 2                  Walk Up
# 3                Weekender
# 4                  Local30
# 5  U.T. Student Membership

# %%
df_1 = client.query('''

select
  subscriber_type,
  avg(duration_minutes) as rata_rata_durasi
from `ftds-hacktiv8-project.practice.bike_rent`
where subscriber_type = 'U.T. Student Membership' or subscriber_type = 'Local30'
group by subscriber_type

''').to_dataframe()

df_1
# Out:
#            subscriber_type  rata_rata_durasi
# 0                  Local30         16.021672
# 1  U.T. Student Membership         39.000000

# %%
# working area
df_1 = client.query('''

select
  subscriber_type,
  avg(duration_minutes) as avg_duration
from `ftds-hacktiv8-project.practice.bike_rent`
where subscriber_type = 'U.T. Student Membership' OR subscriber_type = 'Local30'
group by subscriber_type

''').to_dataframe()

df_1
# Out:
#            subscriber_type  avg_duration
# 0                  Local30     16.021672
# 1  U.T. Student Membership     39.000000

# %% [markdown]
# #####7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).

# %%
df_1 = client.query('''

SELECT *
FROM `ftds-hacktiv8-project.practice.bike_rent`


''').to_dataframe()

df_1
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %%
df_1 = client.query('''

select *
from
(
  select *, duration_minutes / 60 as durasi_jam
  from `ftds-hacktiv8-project.practice.bike_rent`)

where durasi_jam > 4.25

''').to_dataframe()

df_1
# Out:
#      trip_id subscriber_type bike_id bike_type                start_time  \
# 0   13255686         Walk Up     539   classic 2016-12-25 11:17:16+00:00
# 1   13255691         Walk Up     453   classic 2016-12-25 11:18:17+00:00
# 2   14534164         Walk Up     664   classic 2017-04-21 20:46:17+00:00
# 3   14534142         Walk Up     275   classic 2017-04-21 20:41:54+00:00
# 4   11965934         Walk Up     453   classic 2016-09-17 11:55:23+00:00
# ..       ...             ...     ...       ...                       ...
# 86  14699898         Walk Up     262   classic 2017-05-06 09:08:08+00:00
# 87   9516320         Walk Up     157   classic 2016-04-11 13:19:09+00:00
# 88  14465838         Walk Up     871   classic 2017-04-16 12:39:51+00:00
# 89  15884138         Walk Up     882   classic 2017-09-07 19:11:26+00:00
# 90  14087008         Walk Up     221   classic 2017-03-18 00:14:37+00:00
#
#                          start_station_name  \
# 0                                Pease Park
# 1                                Pease Park
# 2                    Davis at Rainey Street
# 3                    Davis at Rainey Street
# 4           Bullock Museum @ Congress & MLK
# ..                                      ...
# 86          State Capitol @ 14th & Colorado
# 87                             Lavaca & 6th
# 88                 South Congress & Academy
# 89  Capital Metro HQ - East 5th at Broadway
# 90              East 6th at Robert Martinez
#
#                            end_station_name  duration_minutes  durasi_jam
# 0                                Pease Park               351    5.850000
# 1                                Pease Park               350    5.833333
# 2                                Pease Park               783   13.050000
# 3                                Pease Park               789   13.150000
# 4                              Lavaca & 6th               325    5.416667
# ..                                      ...               ...         ...
# 86          State Capitol @ 14th & Colorado               350    5.833333
# 87          State Capitol @ 14th & Colorado               643   10.716667
# 88          State Capitol @ 14th & Colorado               684   11.400000
# 89  Capital Metro HQ - East 5th at Broadway               292    4.866667
# 90  Capital Metro HQ - East 5th at Broadway               757   12.616667
#
# [91 rows x 9 columns]

# %%
# working area
df_1 = client.query('''

select *
from
  (
  select *, duration_minutes / 60 AS duration_jam
  from `ftds-hacktiv8-project.practice.bike_rent`)

WHERE duration_jam > 4.25

''').to_dataframe()

df_1
# Out:
#      trip_id subscriber_type bike_id bike_type                start_time  \
# 0   13255686         Walk Up     539   classic 2016-12-25 11:17:16+00:00
# 1   13255691         Walk Up     453   classic 2016-12-25 11:18:17+00:00
# 2   14534164         Walk Up     664   classic 2017-04-21 20:46:17+00:00
# 3   14534142         Walk Up     275   classic 2017-04-21 20:41:54+00:00
# 4   11965934         Walk Up     453   classic 2016-09-17 11:55:23+00:00
# ..       ...             ...     ...       ...                       ...
# 86  14699898         Walk Up     262   classic 2017-05-06 09:08:08+00:00
# 87   9516320         Walk Up     157   classic 2016-04-11 13:19:09+00:00
# 88  14465838         Walk Up     871   classic 2017-04-16 12:39:51+00:00
# 89  15884138         Walk Up     882   classic 2017-09-07 19:11:26+00:00
# 90  14087008         Walk Up     221   classic 2017-03-18 00:14:37+00:00
#
#                          start_station_name  \
# 0                                Pease Park
# 1                                Pease Park
# 2                    Davis at Rainey Street
# 3                    Davis at Rainey Street
# 4           Bullock Museum @ Congress & MLK
# ..                                      ...
# 86          State Capitol @ 14th & Colorado
# 87                             Lavaca & 6th
# 88                 South Congress & Academy
# 89  Capital Metro HQ - East 5th at Broadway
# 90              East 6th at Robert Martinez
#
#                            end_station_name  duration_minutes  duration_jam
# 0                                Pease Park               351      5.850000
# 1                                Pease Park               350      5.833333
# 2                                Pease Park               783     13.050000
# 3                                Pease Park               789     13.150000
# 4                              Lavaca & 6th               325      5.416667
# ..                                      ...               ...           ...
# 86          State Capitol @ 14th & Colorado               350      5.833333
# 87          State Capitol @ 14th & Colorado               643     10.716667
# 88          State Capitol @ 14th & Colorado               684     11.400000
# 89  Capital Metro HQ - East 5th at Broadway               292      4.866667
# 90  Capital Metro HQ - East 5th at Broadway               757     12.616667
#
# [91 rows x 9 columns]

# %%
# working area
df_1 = client.query('''

select
  *,
  duration_minutes/60 AS convert_time
from `ftds-hacktiv8-project.practice.bike_rent`
WHERE
  duration_minutes/60 > 4.25

''').to_dataframe()

df_1
# Out:
#      trip_id subscriber_type bike_id bike_type                start_time  \
# 0   13255686         Walk Up     539   classic 2016-12-25 11:17:16+00:00
# 1   13255691         Walk Up     453   classic 2016-12-25 11:18:17+00:00
# 2   14534164         Walk Up     664   classic 2017-04-21 20:46:17+00:00
# 3   14534142         Walk Up     275   classic 2017-04-21 20:41:54+00:00
# 4   11965934         Walk Up     453   classic 2016-09-17 11:55:23+00:00
# ..       ...             ...     ...       ...                       ...
# 86  14699898         Walk Up     262   classic 2017-05-06 09:08:08+00:00
# 87   9516320         Walk Up     157   classic 2016-04-11 13:19:09+00:00
# 88  14465838         Walk Up     871   classic 2017-04-16 12:39:51+00:00
# 89  15884138         Walk Up     882   classic 2017-09-07 19:11:26+00:00
# 90  14087008         Walk Up     221   classic 2017-03-18 00:14:37+00:00
#
#                          start_station_name  \
# 0                                Pease Park
# 1                                Pease Park
# 2                    Davis at Rainey Street
# 3                    Davis at Rainey Street
# 4           Bullock Museum @ Congress & MLK
# ..                                      ...
# 86          State Capitol @ 14th & Colorado
# 87                             Lavaca & 6th
# 88                 South Congress & Academy
# 89  Capital Metro HQ - East 5th at Broadway
# 90              East 6th at Robert Martinez
#
#                            end_station_name  duration_minutes  convert_time
# 0                                Pease Park               351      5.850000
# 1                                Pease Park               350      5.833333
# 2                                Pease Park               783     13.050000
# 3                                Pease Park               789     13.150000
# 4                              Lavaca & 6th               325      5.416667
# ..                                      ...               ...           ...
# 86          State Capitol @ 14th & Colorado               350      5.833333
# 87          State Capitol @ 14th & Colorado               643     10.716667
# 88          State Capitol @ 14th & Colorado               684     11.400000
# 89  Capital Metro HQ - East 5th at Broadway               292      4.866667
# 90  Capital Metro HQ - East 5th at Broadway               757     12.616667
#
# [91 rows x 9 columns]

# %% [markdown]
# ###**Pandas**

# %% [markdown]
# #####Data Loading

# %%
# working area
data_table = client.query('''
SELECT *
FROM `ftds-hacktiv8-project.practice.bike_rent`
''').to_dataframe()

data_table
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %% [markdown]
# #####1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`

# %%
data_table.isnull()
# Out:
#       trip_id  subscriber_type  bike_id  bike_type  start_time  \
# 0       False            False    False      False       False
# 1       False            False    False      False       False
# 2       False            False    False      False       False
# 3       False            False    False      False       False
# 4       False            False    False      False       False
# ...       ...              ...      ...        ...         ...
# 7995    False            False    False      False       False
# 7996    False            False    False      False       False
# 7997    False            False    False      False       False
# 7998    False            False    False      False       False
# 7999    False            False    False      False       False
#
#       start_station_name  end_station_name  duration_minutes
# 0                  False             False             False
# 1                  False             False             False
# 2                  False             False             False
# 3                  False             False             False
# 4                  False             False             False
# ...                  ...               ...               ...
# 7995               False             False             False
# 7996               False             False             False
# 7997               False             False             False
# 7998               False             False             False
# 7999               False             False             False
#
# [8000 rows x 8 columns]

# %%
# working area
data_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_id             8000 non-null   Int64
#  1   subscriber_type     8000 non-null   object
#  2   bike_id             8000 non-null   object
#  3   bike_type           8000 non-null   object
#  4   start_time          8000 non-null   datetime64[ns, UTC]
#  5   start_station_name  8000 non-null   object
#  6   end_station_name    8000 non-null   object
#  7   duration_minutes    8000 non-null   Int64
#  8   quarter             8000 non-null   object
# dtypes: Int64(2), datetime64[ns, UTC](1), object(6)
# memory usage: 578.2+ KB

# %% [markdown]
# #####2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`.
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
# working area
import pandas as pd

# %%
df = pd.DataFrame (data_table)

quarter = []

for data in df['start_time'].dt.month:
  if data in (1,2,3):
    quarter.append('Q1')
  elif data in (4,5,6):
    quarter.append('Q2')
  elif data in (7,8,9):
    quarter.append('Q3')
  elif data in (10,11,12):
    quarter.append('Q4')

df['quarter'] = quarter

df
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes quarter
# 0                              11th & Salina                178      Q4
# 1                                 Main Office               198      Q1
# 2                                 Main Office                60      Q4
# 3                                 Main Office                60      Q4
# 4                                 Main Office                60      Q4
# ...                                       ...               ...     ...
# 7995          Bullock Museum @ Congress & MLK                55      Q3
# 7996          Bullock Museum @ Congress & MLK                55      Q4
# 7997          State Capitol @ 14th & Colorado                55      Q1
# 7998          State Capitol @ 14th & Colorado                55      Q2
# 7999  Capital Metro HQ - East 5th at Broadway                55      Q2
#
# [8000 rows x 9 columns]

# %% [markdown]
# #####3. Tampilkan data perjalanan dari tipe member `Local31` dengan durasi perjalanan diatas 1 jam.
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
df['subscriber_type'].unique()
# Out:
# array(['Explorer', 'Local365', 'Walk Up', 'Weekender', 'Local30',
#        'U.T. Student Membership'], dtype=object)

# %%
# working area

df = pd.DataFrame (data_table)

df.loc[(df['subscriber_type'] == 'Local30') & (df['duration_minutes'] > 60)]
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 24    13903148         Local30      62   classic 2017-03-02 17:26:17+00:00
# 39    11900970         Local30     666   classic 2016-09-13 12:19:41+00:00
# 42    11918705         Local30     200   classic 2016-09-14 12:33:27+00:00
# 47    12111057         Local30     930   classic 2016-09-27 11:54:40+00:00
# 56    12563092         Local30     464   classic 2016-10-26 11:54:07+00:00
# 64    12458429         Local30     513   classic 2016-10-19 12:16:29+00:00
# 149   14638999         Local30     432   classic 2017-05-01 07:23:30+00:00
# 157   15065592         Local30      88   classic 2017-06-08 16:02:58+00:00
# 201   13526115         Local30     277   classic 2017-01-24 07:27:33+00:00
# 263   14729536         Local30     114   classic 2017-05-08 15:45:34+00:00
# 343   12065614         Local30     452   classic 2016-09-23 23:00:11+00:00
# 374   15865752         Local30     198   classic 2017-09-05 17:14:36+00:00
# 440   14968922         Local30     875   classic 2017-05-29 14:13:44+00:00
# 670   12523096         Local30     589   classic 2016-10-23 18:55:47+00:00
# 683   14766785         Local30     881   classic 2017-05-11 21:01:13+00:00
# 808   16404425         Local30     156   classic 2017-11-19 16:17:14+00:00
# 813   16457909         Local30     414   classic 2017-11-30 20:09:15+00:00
# 1188   9690519         Local30     105   classic 2016-04-23 16:32:30+00:00
#
#                    start_station_name  \
# 24                         Pease Park
# 39                       Lavaca & 6th
# 42                       Lavaca & 6th
# 47                       Lavaca & 6th
# 56                       Lavaca & 6th
# 64                       Lavaca & 6th
# 149            Davis at Rainey Street
# 157            Davis at Rainey Street
# 201            Davis at Rainey Street
# 263   Bullock Museum @ Congress & MLK
# 343                11th & San Jacinto
# 374                11th & San Jacinto
# 440   State Capitol @ 14th & Colorado
# 670     Pfluger Bridge @ W 2nd Street
# 683                 Palmer Auditorium
# 808    East 11th St. at Victory Grill
# 813    East 11th St. at Victory Grill
# 1188                 5th & San Marcos
#
#                              end_station_name  duration_minutes quarter
# 24                                 Pease Park                90      Q1
# 39                               Lavaca & 6th                73      Q3
# 42                               Lavaca & 6th                66      Q3
# 47                               Lavaca & 6th                71      Q3
# 56                               Lavaca & 6th                62      Q4
# 64                               Lavaca & 6th                75      Q4
# 149                              Lavaca & 6th               137      Q2
# 157                              Lavaca & 6th               174      Q2
# 201                           Guadalupe & 6th               138      Q1
# 263                          17th & Guadalupe               497      Q2
# 343                        11th & San Jacinto                71      Q3
# 374                        11th & San Jacinto               409      Q3
# 440                        13th & San Antonio               106      Q2
# 670                Barton Springs & Riverside               308      Q4
# 683                Barton Springs & Riverside               182      Q2
# 808            East 11th St. at Victory Grill               112      Q4
# 813            East 11th St. at Victory Grill               190      Q4
# 1188  Capital Metro HQ - East 5th at Broadway               146      Q2

# %% [markdown]
# #####4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` dari data yang diambil?
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
# working area
df = pd.DataFrame (data_table)

rata_rata_durasi = df.loc[(df['subscriber_type'] == 'Walk Up') & (df['bike_type'] == 'classic')
        & (df['start_time'].dt.month == 3 )]

rata_rata_durasi ['duration_minutes'].mean()
# Out:
# 38.476584022038566
